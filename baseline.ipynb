# %% [markdown]
# ### Original Imbalanced Data

# %%
from load_dataset import load_dataset
train_df = load_dataset(file_path="/Users/nijiayi/Stats_C161-261_Project/train_data_after_feature_selection.csv")
test_df = load_dataset(file_path="/Users/nijiayi/Stats_C161-261_Project/test_data_after_feature_selection.csv")
X_train = train_df.drop(columns=["label"])
y_train = train_df["label"]
X_test = test_df.drop(columns=["label"])
y_test = test_df["label"]
X_train.shape, X_test.shape
# Out:
# 4it [00:04,  1.15s/it]
# 1it [00:00, 42.48it/s]
# ((3813974, 22), (23784, 22))

# %%
from collections import Counter
print("Class distribution for the train set:", Counter(y_train))
# Out:
# Class distribution for the train set: Counter({0: 3766407, 1: 47567})

# %%
import matplotlib.pyplot as plt

train_class_counts = {0: 3766407, 1: 47567}
test_class_counts = {0: 11892, 1: 11892}

labels = ["Class 0", "Class 1"]
train_sizes = [train_class_counts[0], train_class_counts[1]]
test_sizes = [test_class_counts[0], test_class_counts[1]]

plt.figure(figsize=(8, 6))
plt.pie(train_sizes, labels=labels, autopct="%1.1f%%", startangle=90)
plt.title("Class Distribution in Train Set")
plt.show()

# Plotting pie chart for test set
plt.figure(figsize=(8, 6))
plt.pie(test_sizes, labels=labels, autopct="%1.1f%%", startangle=90)
plt.title("Class Distribution in Test Set")
plt.show()

# %%
from collections import Counter
print("Class distribution for the test set:", Counter(y_test))
# Out:
# Class distribution for the test set: Counter({1: 11892, 0: 11892})

# %%
from evaluation.utility import *
# Logistic Regression
evaluate(method="logistic_regression", X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 23779    0
# 23780    0
# 23781    0
# 23782    0
# 23783    0
# Name: label, Length: 23784, dtype: int64
# [0 0 0 ... 0 0 0]
# Evaluation metrics for logistic_regression:
# ROC-AUC: 0.75430
# Accuracy: 0.50000
# Recall: 0.00000
# F1-Score: 0.00000
# {'ROC-AUC': 0.7542978075524207,
#  'Accuracy': 0.5,
#  'Recall': 0.0,
#  'F1-Score': 0.0}

# %%
from evaluation.utility import *
# Logistic Regression
evaluate(method="logistic_regression", X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Random Forest
evaluate(method="random_forest", X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Catboost
evaluate(method="catboost", X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Out:
# Evaluation metrics for logistic_regression:
# ROC-AUC: 0.75430
# Accuracy: 0.50000
# Recall: 0.00000
# F1-Score: 0.00000
# Evaluation metrics for random_forest:
# ROC-AUC: 0.74653
# Accuracy: 0.55584
# Recall: 0.11436
# F1-Score: 0.20476
# Evaluation metrics for catboost:
# ROC-AUC: 0.81301
# Accuracy: 0.52262
# Recall: 0.04591
# F1-Score: 0.08774
# {'ROC-AUC': 0.8130069203106012,
#  'Accuracy': 0.5226202489068281,
#  'Recall': 0.04591321897073663,
#  'F1-Score': 0.08773903262092239}
